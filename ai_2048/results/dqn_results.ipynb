# %%
import pandas as pd

# %%
data_dqn = pd.read_pickle("results/grid_search-2000k_steps-256_hidden-batch_size_128-zero_inv_rew/test_results_best-pandas.pickle")
data_supervised = pd.read_pickle("results/supervised-0k_games-256_hidden-512_min_score-V3/epochs_evaluation_best-supervised-0k_games-256_hidden-512_min_score-V3.pickle")

# %%
data_dqn.sort_values(by=[("dqn", "mean_highest_value")], ascending=False).to_excel("results/results_dqn_sorted.xlsx", engine="xlsxwriter", float_format="%.2f")

# %%
data_supervised
# Out:
#     n_games                                nn                    \
#     n_games n_observations mean_episode_score max_episode_score
# 0 0     101          31652              795.2              1328
#   0     202          63607             1259.2              2544
#   0     303          95352             1085.2              2904
# 1 0     101          31652             1246.0              2720
#   0     202          63607             1194.0              2448
#   0     303          95352             1443.6              2780
# 2 0     101          31652             1112.4              1600
#   0     202          63607             1214.4              2640
#   0     303          95352             1237.2              2848
#
#                                                                              \
#     mean_highest_value max_highest_value mean_nb_env_steps max_nb_env_steps
# 0 0               76.8               128             171.5              293
# ...
